# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
dimensiones=[3,4,5,6,7,8,9,10]
puntos_mal_predichos=[22,6, 6, 5, 6, 6,6,0 ]
puntos_bien_predichos=[42-22,6, 6, 5, 6, 6,6,0 ]
plt.plot(dimensiones,puntos_mal_predichos,'-.')
plt.xlabel('Dimensiones')
plt.ylabel('# muestras mal predichos')
# Out:
# Text(0, 0.5, '#Puntos mal predichos')
